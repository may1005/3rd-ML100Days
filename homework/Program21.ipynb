# %% [markdown]
# ### Input : Fun(6)
#
# ### Output : 1,2,3,4,5,6

# %%
def fun(num):
    num_list = []
    for i in range(1, num+1):
        num_list += [i] 
    return num_list

# %%
fun(6)
# Out:
# [1, 2, 3, 4, 5, 6]
