# %% [markdown]
# # 作業目標:¶
# 利用手寫辨識資料說明MLP 中, 神經網路層的多寡跟預測結果的差異

# %% [markdown]
# # 作業重點:
# [練習]請嘗試新增一層或兩層看看最後預測結果是否有差異
# model.add(Dense(units=256, input_dim=784, kernel_initializer='normal', activation='relu'))

# %% [markdown]
# # 資料預處理

# %%
from keras.utils import np_utils
import numpy as np
np.random.seed(10)
# Out:
# Using TensorFlow backend.

# %%
#載入手寫辨識的資料集
from keras.datasets import mnist
(x_train_image,y_train_label),\
(x_test_image,y_test_label)= mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 115s 10us/step

# %%
#指定測試集與訓練資料集
x_Train =x_train_image.reshape(60000, 784).astype('float32')
x_Test = x_test_image.reshape(10000, 784).astype('float32')

# %%
# normalize inputs from 0-255 to 0-1
x_Train_normalize = x_Train / 255
x_Test_normalize = x_Test / 255

# %%
#把LABEL轉成NUMERICAL Categorical 
y_Train_OneHot = np_utils.to_categorical(y_train_label)
y_Test_OneHot = np_utils.to_categorical(y_test_label)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#建立模型
model = Sequential()

# %%
#建構輸入層
model.add(Dense(units=256, 
                input_dim=784, 
                kernel_initializer='normal', 
                activation='relu'))

model.add(Dense(units=256, 
                kernel_initializer='normal', 
                activation='relu'))

model.add(Dense(units=256, 
                kernel_initializer='normal', 
                activation='relu'))

# %%
#建構輸出層
model.add(Dense(units=10, 
                kernel_initializer='normal', 
                activation='softmax'))

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               200960
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 335,114
# Trainable params: 335,114
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# # 訓練模型

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

# %%
train_history =model.fit(x=x_Train_normalize,
                         y=y_Train_OneHot,validation_split=0.2, 
                         epochs=10, batch_size=32,verbose=1)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/10
# 48000/48000 [==============================] - 7s 147us/step - loss: 0.2387 - accuracy: 0.9279 - val_loss: 0.1014 - val_accuracy: 0.9688
# Epoch 2/10
# 48000/48000 [==============================] - 6s 125us/step - loss: 0.0998 - accuracy: 0.9701 - val_loss: 0.0938 - val_accuracy: 0.9708
# Epoch 3/10
# 48000/48000 [==============================] - 6s 129us/step - loss: 0.0704 - accuracy: 0.9780 - val_loss: 0.0960 - val_accuracy: 0.9722
# Epoch 4/10
# 48000/48000 [==============================] - 6s 118us/step - loss: 0.0516 - accuracy: 0.9834 - val_loss: 0.1086 - val_accuracy: 0.9691
# Epoch 5/10
# 48000/48000 [==============================] - 6s 121us/step - loss: 0.0432 - accuracy: 0.9861 - val_loss: 0.1026 - val_accuracy: 0.9732
# Epoch 6/10
# 48000/48000 [==============================] - 6s 119us/step - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.0940 - val_accuracy: 0.9758
# Epoch 7/10
# 48000/48000 [==============================] - 6s 122us/step - loss: 0.0325 - accuracy: 0.9901 - val_loss: 0.1025 - val_accuracy: 0.9753
# Epoch 8/10
# 48000/48000 [==============================] - 6s 125us/step - loss: 0.0251 - accuracy: 0.9924 - val_loss: 0.1114 - val_accuracy: 0.9751
# Epoch 9/10
# 48000/48000 [==============================] - 6s 129us/step - loss: 0.0246 - accuracy: 0.9924 - val_loss: 0.1121 - val_accuracy: 0.9776
# Epoch 10/10
# 48000/48000 [==============================] - 7s 146us/step - loss: 0.0248 - accuracy: 0.9924 - val_loss: 0.1075 - val_accuracy: 0.9764

# %% [markdown]
# # 以圖形顯示訓練過程

# %%
import matplotlib.pyplot as plt
def show_train_history(train_history,train,validation):
    plt.plot(train_history.history[train])
    plt.plot(train_history.history[validation])
    plt.title('Train History')
    plt.ylabel(train)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')
    plt.show()

# %%
show_train_history(train_history,'acc','val_acc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-0f5605080d27> in <module>
# ----> 1 show_train_history(train_history,'acc','val_acc')
#
# <ipython-input-16-48448a1ec165> in show_train_history(train_history, train, validation)
#       1 import matplotlib.pyplot as plt
#       2 def show_train_history(train_history,train,validation):
# ----> 3     plt.plot(train_history.history[train])
#       4     plt.plot(train_history.history[validation])
#       5     plt.title('Train History')
#
# KeyError: 'acc'

# %%
show_train_history(train_history,'loss','val_loss')

# %% [markdown]
# # 評估模型準確率

# %%
scores = model.evaluate(x_Test_normalize, y_Test_OneHot)
print()
print('accuracy=',scores[1])
